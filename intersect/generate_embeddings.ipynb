# %%
import pandas as pd
from embedding import get_embedding

URL = "data/jobs2.feather"
df = pd.read_feather(URL)
df
# Out:
#                                                 title  \
# 0                                         AI Engineer
# 1                               AI Solution Architect
# 2                                  Senior AI Engineer
# 3                               Head of AI - Robotics
# 4                                   Data Planner - AI
# 5                AI Software Engineer C# .Net ChatGPT
# 6              Lead Gen AI/ML Engineer (Python/React)
# 7                                        Data Planner
# 8                         Head AI Transformation Lead
# 9                Manipulation Lead - Robotic Software
# 10               Machine Learning Engineering Manager
# 11                     Lead Backend Software Engineer
# 12           Backend Software Engineer Python AI SaaS
# 13       Backend Software Engineer C# .Net AI ChatGPT
# 14  AI / Tech Training Solutions - Business Develo...
# 15  Senior Digital Project Manager, AI, Mainly Remote
# ...

# %%
# df["embedding"] = df["description"].apply(get_embedding)
df
# Out:
#                                                 title  \
# 0                                         AI Engineer
# 1                               AI Solution Architect
# 2                                  Senior AI Engineer
# 3                               Head of AI - Robotics
# 4                                   Data Planner - AI
# 5                AI Software Engineer C# .Net ChatGPT
# 6              Lead Gen AI/ML Engineer (Python/React)
# 7                                        Data Planner
# 8                         Head AI Transformation Lead
# 9                Manipulation Lead - Robotic Software
# 10               Machine Learning Engineering Manager
# 11                     Lead Backend Software Engineer
# 12           Backend Software Engineer Python AI SaaS
# 13       Backend Software Engineer C# .Net AI ChatGPT
# 14  AI / Tech Training Solutions - Business Develo...
# 15  Senior Digital Project Manager, AI, Mainly Remote
# ...

# %%
df.to_feather(URL)
